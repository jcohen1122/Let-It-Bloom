# %%
import pandas as pd
import csv

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
#HOW TO GET DATA FILE INTO COLAB

#Copy the Koppen Geiger data folder from our shared folder and paste it into your own google drive
#Run the second cell importing drive from google.colab and allow access to your drive
#Once it displays Mounted at/content/drive :
  #Refresh -> Click files -> MyDrive -> Your Koppen Geiger Data folder -> Right click on a file -> Copy path
#Now you can do the following
  #Right click on your data folder and create a new csv file to write the code into
  #Use the txt path for the first one and the csv path for the second and third one
  #Change the df_ob01_25 and df_ob01 variables to your model and year
  #Change the ['1901-1925'] to your year
#Run the cell

# %%
#Observed 1901-1925

#read txt file into csv, then convert to a dataframe and clean data
ob_1901_25 = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/Observed-1901-1925.txt')
#Make sure second and third paths are .csv and not .txt
ob_1901_25.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/Observed_Data.csv', index = None)

df_ob01 = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/Observed_Data.csv')
df_ob01 = df_ob01['1901-1925'].str.split(expand = True)
df_ob01.columns = ['Lat','Lon','Cls']
df_ob01.drop(0, inplace= True)
df_ob01 = df_ob01.reset_index(drop=True)
df_ob01.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/1901-25 Observed_Data.csv')

# %%
#Observed 1926-1950

#read txt file into csv, then convert to a dataframe and clean data
ob_1926 = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/Observed_1926-1950.txt')
#Make sure second and third paths are .csv and not .txt
ob_1926.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/Observed_Data_26.csv', index = None)

df_ob26 = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/Observed_Data_26.csv')
df_ob26 = df_ob26['1926-1950'].str.split(expand = True)
df_ob26.columns = ['Lat','Lon','Cls']
df_ob26.drop(0, inplace= True)
df_ob26 = df_ob26.reset_index(drop=True)
df_ob26.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/1926-50 Observed_Data.csv')

# %%
#Observed 1951-1975

#read txt file into csv, then convert to a dataframe and clean data
ob_1951 = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/Observed_1951-1975.txt')
#Make sure second and third paths are .csv and not .txt
ob_1951.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/Observed_Data_51.csv', index = None)

df_ob51 = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/Observed_Data_51.csv')
df_ob51 = df_ob51['1951-1975'].str.split(expand = True)
df_ob51.columns = ['Lat','Lon','Cls']
df_ob51.drop(0, inplace= True)
df_ob51 = df_ob26.reset_index(drop=True)
df_ob51.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/1951-75 Observed_Data.csv')

# %%
#Observed 1976-2000

#read txt file into csv, then convert to a dataframe and clean data
ob_1976 = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/Observed_1976-2000.txt')
#Make sure second and third paths are .csv and not .txt
ob_1976.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/Observed_Data_76.csv', index = None)

df_ob76 = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/Observed_Data_76.csv')
df_ob76 = df_ob76['1976-2000'].str.split(expand = True)
df_ob76.columns = ['Lat','Lon','Cls']
df_ob76.drop(0, inplace= True)
df_ob76 = df_ob26.reset_index(drop=True)
df_ob76.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/1976-2000 Observed_Data.csv')

# %%
#Observed 2001-2025 A1FI

#read txt file into csv, then convert to a dataframe and clean data
data = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/2001-2025_A1FI_ASCII.txt')
#Make sure second and third paths are .csv and not .txt
data.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2001-2025 A1FI.csv', index = None)

df = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2001-2025 A1FI.csv')
df = df['2001-2025 A1FI'].str.split(expand = True)
df.columns = ['Lat','Lon','Cls']
df.drop(0, inplace= True)
df = df.reset_index(drop=True)
df.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2001-2025 A1FI.csv')

# %%
#Observed 2026-2050 A1FI

#read txt file into csv, then convert to a dataframe and clean data
data = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/2026-2050_A1FI_ASCII.txt')
#Make sure second and third paths are .csv and not .txt
data.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2026-2050 A1FI.csv', index = None)

df = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2026-2050 A1FI.csv')
df = df['2026-2050 A1FI'].str.split(expand = True)
df.columns = ['Lat','Lon','Cls']
df.drop(0, inplace= True)
df = df.reset_index(drop=True)
df.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2026-2050 A1FI.csv')

# %%
#Observed 2051-2075 A1FI

#read txt file into csv, then convert to a dataframe and clean data
data = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/2051-2075_A1FI_ASCII.txt')
#Make sure second and third paths are .csv and not .txt
data.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2051-2075 A1F1.csv', index = None)

df = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2051-2075 A1F1.csv')
df = df['2051-2075 A1FI'].str.split(expand = True)
df.columns = ['Lat','Lon','Cls']
df.drop(0, inplace= True)
df = df.reset_index(drop=True)
df.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2051-2075 A1FI.csv')

# %%
#Observed 2076-2100 A1FI

#read txt file into csv, then convert to a dataframe and clean data
data = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/2076-2100_A1FI_ASCII.txt')
#Make sure second and third paths are .csv and not .txt
data.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2076-2100 A1FI.csv', index = None)

df = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2076-2100 A1FI.csv')
df = df['2076-2100 A1FI'].str.split(expand = True)
df.columns = ['Lat','Lon','Cls']
df.drop(0, inplace= True)
df = df.reset_index(drop=True)
df.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2076-2100 A1FI.csv')

# %%
#Observed 2001-2025 A2

#read txt file into csv, then convert to a dataframe and clean data
data = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/2001-2025_A2_ASCII.txt')
#Make sure second and third paths are .csv and not .txt
data.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2001-2025 A2.csv', index = None)

df = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2001-2025 A2.csv')
df = df['2001-2025 A2'].str.split(expand = True)
df.columns = ['Lat','Lon','Cls']
df.drop(0, inplace= True)
df = df.reset_index(drop=True)
df.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2001-2025 A2.csv')

# %%
#Observed 2026-2050 A2

#read txt file into csv, then convert to a dataframe and clean data
data = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/2026-2050_A2_ASCII.txt')
#Make sure second and third paths are .csv and not .txt
data.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2026-2050 A2.csv', index = None)

df = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2026-2050 A2.csv')
df = df['2026-2050 A2'].str.split(expand = True)
df.columns = ['Lat','Lon','Cls']
df.drop(0, inplace= True)
df = df.reset_index(drop=True)
df.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2026-2050 A2.csv')

# %%
#Observed 2051-2075 A2

#read txt file into csv, then convert to a dataframe and clean data
data = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/2051-2075_A2_ASCII.txt')
#Make sure second and third paths are .csv and not .txt
data.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2051-2075 A2.csv', index = None)

df = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2051-2075 A2.csv')
df = df['2051-2075 A2'].str.split(expand = True)
df.columns = ['Lat','Lon','Cls']
df.drop(0, inplace= True)
df = df.reset_index(drop=True)
df.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2051-2075 A2.csv')

# %%
#Observed 2076-2100 A2

#read txt file into csv, then convert to a dataframe and clean data
data = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/2076-2100_A2_ASCII.txt')
#Make sure second and third paths are .csv and not .txt
data.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2076-2100 A2.csv', index = None)

df = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2076-2100 A2.csv')
df = df['2076-2100 A2'].str.split(expand = True)
df.columns = ['Lat','Lon','Cls']
df.drop(0, inplace= True)
df = df.reset_index(drop=True)
df.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2076-2100 A2.csv')

# %%
#Observed 2001-2025 B1

#read txt file into csv, then convert to a dataframe and clean data
data = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/2001-2025_B1_ASCII.txt')
#Make sure second and third paths are .csv and not .txt
data.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2001-2025 B1.csv', index = None)

df = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2001-2025 B1.csv')
df = df['2001-2025 B1'].str.split(expand = True)
df.columns = ['Lat','Lon','Cls']
df.drop(0, inplace= True)
df = df.reset_index(drop=True)
df.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2001-2025 B1.csv')

# %%
#Observed 2026-2050 B1

#read txt file into csv, then convert to a dataframe and clean data
data = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/2026-2050_B1_ASCII.txt')
#Make sure second and third paths are .csv and not .txt
data.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2026-2050 B1.csv', index = None)

df = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2026-2050 B1.csv')
df = df['2026-2050 B1'].str.split(expand = True)
df.columns = ['Lat','Lon','Cls']
df.drop(0, inplace= True)
df = df.reset_index(drop=True)
df.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2026-2050 B1.csv')

# %%
#Observed 2051-2075 B1

#read txt file into csv, then convert to a dataframe and clean data
data = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/2051-2075_B1_ASCII.txt')
#Make sure second and third paths are .csv and not .txt
data.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2051-2075 B1.csv', index = None)

df = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2051-2075 B1.csv')
df = df['2051-2075 B1'].str.split(expand = True)
df.columns = ['Lat','Lon','Cls']
df.drop(0, inplace= True)
df = df.reset_index(drop=True)
df.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2051-2075 B1.csv')

# %%
#Observed 2076-2100 B1

#read txt file into csv, then convert to a dataframe and clean data
data = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/2076-2100_B1_ASCII.txt')
#Make sure second and third paths are .csv and not .txt
data.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2076-2100 B1.csv', index = None)

df = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2076-2100 B1.csv')
df = df['2076-2100 B1'].str.split(expand = True)
df.columns = ['Lat','Lon','Cls']
df.drop(0, inplace= True)
df = df.reset_index(drop=True)
df.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2076-2100 B1.csv')

# %%
#Observed 2001-2025 B2

#read txt file into csv, then convert to a dataframe and clean data
data = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/2001-2025_B2_ASCII (1).txt')
#Make sure second and third paths are .csv and not .txt
data.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2001-2025 B2.csv', index = None)

df = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2001-2025 B2.csv')
df = df['2001-2025 B2'].str.split(expand = True)
df.columns = ['Lat','Lon','Cls']
df.drop(0, inplace= True)
df = df.reset_index(drop=True)
df.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2001-2025 B2.csv')

# %%
#Observed 2026-2050 B2

#read txt file into csv, then convert to a dataframe and clean data
data = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/2026-2050_B2_ASCII.txt')
#Make sure second and third paths are .csv and not .txt
data.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2026-2050 B2.csv', index = None)

df = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2026-2050 B2.csv')
df = df['2026-2050 B2'].str.split(expand = True)
df.columns = ['Lat','Lon','Cls']
df.drop(0, inplace= True)
df = df.reset_index(drop=True)
df.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2026-2050 B2.csv')

# %%
#Observed 2051-2075 B2

#read txt file into csv, then convert to a dataframe and clean data
data = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/2051-2075_B2_ASCII.txt')
#Make sure second and third paths are .csv and not .txt
data.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2051-2075 B2.csv', index = None)

df = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2051-2075 B2.csv')
df = df['2051-2075 B2'].str.split(expand = True)
df.columns = ['Lat','Lon','Cls']
df.drop(0, inplace= True)
df = df.reset_index(drop=True)
df.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2051-2075 B2.csv')

# %%
#Observed 2076-2100 B2

#read txt file into csv, then convert to a dataframe and clean data
data = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger Data/2076-2100_B2_ASCII.txt')
#Make sure second and third paths are .csv and not .txt
data.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2076-2100 B2.csv', index = None)

df = pd.read_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2076-2100 B2.csv')
df = df['2076-2100 B2'].str.split(expand = True)
df.columns = ['Lat','Lon','Cls']
df.drop(0, inplace= True)
df = df.reset_index(drop=True)
df.to_csv('/content/drive/MyDrive/Tamid Group/Let it Bloom/Koppen Geiger CSV Files/2076-2100 B2.csv')

# %%
#ignore cells below this

# %%
#Convert Climate designations to numbers to be able to graph
#Grouped by first digit in order to sort
df_ob01 = df_ob01.replace(to_replace ="Af", value = int("11"))
df_ob01 = df_ob01.replace(to_replace ="Am", value = int("12"))
df_ob01 = df_ob01.replace(to_replace ="As", value = int("13"))
df_ob01 = df_ob01.replace(to_replace ="Aw", value = int("14"))
df_ob01 = df_ob01.replace(to_replace ="BWk", value = int("21"))
df_ob01 = df_ob01.replace(to_replace ="BWh", value = int("22"))
df_ob01 = df_ob01.replace(to_replace ="BSk", value = int("23"))
df_ob01 = df_ob01.replace(to_replace ="BSh", value = int("24"))
df_ob01 = df_ob01.replace(to_replace ="Cfa", value = int("31"))
df_ob01 = df_ob01.replace(to_replace ="Cfb", value = int("32"))
df_ob01 = df_ob01.replace(to_replace ="Cfc", value = int("33"))
df_ob01 = df_ob01.replace(to_replace ="Csa", value = int("34"))
df_ob01 = df_ob01.replace(to_replace ="Csb", value = int("35"))
df_ob01 = df_ob01.replace(to_replace ="Csc", value = int("36"))
df_ob01 = df_ob01.replace(to_replace ="Cwa", value = int("37"))
df_ob01 = df_ob01.replace(to_replace ="Cwb", value = int("38"))
df_ob01 = df_ob01.replace(to_replace ="Cwc", value = int("39"))
df_ob01 = df_ob01.replace(to_replace ="Dfa", value = int("41"))
df_ob01 = df_ob01.replace(to_replace ="Dfb", value = int("42"))
df_ob01 = df_ob01.replace(to_replace ="Dfc", value = int("43"))
df_ob01 = df_ob01.replace(to_replace ="Dfd", value = int("44"))
df_ob01 = df_ob01.replace(to_replace ="Dsa", value = int("45"))
df_ob01 = df_ob01.replace(to_replace ="Dsb", value = int("46"))
df_ob01 = df_ob01.replace(to_replace ="Dsc", value = int("47"))
df_ob01 = df_ob01.replace(to_replace ="Dsd", value = int("48"))
df_ob01 = df_ob01.replace(to_replace ="Dwa", value = int("49"))
df_ob01 = df_ob01.replace(to_replace ="Dwb", value = int("50"))
df_ob01 = df_ob01.replace(to_replace ="Dwc", value = int("51"))
df_ob01 = df_ob01.replace(to_replace ="Dwd", value = int("52"))
df_ob01 = df_ob01.replace(to_replace ="EF", value = int("61"))
df_ob01 = df_ob01.replace(to_replace ="ET", value = int("62"))

#sort by Climate designation
df_ob01 = df_ob01.sort_values('Cls')
df_ob01

# %%
#histograms
sns.histplot(data=df_ob01, x="Cls", color="skyblue", label="1901-1925")
#sns.histplot(data=df_ob26, x="Cls", color="red", label="1926-1950", alpha = 0.5)
#sns.histplot(data=df_ob51, x="Cls", color="green", label="1951-1975", alpha = 0.5)
sns.histplot(data=df_ob76, x="Cls", color="orange", label="1976-2000", alpha = 0.5)

plt.legend()
plt.show()

# %%
#Climate Zone Density plot
sns.kdeplot(df_ob01['Cls'].astype(float))
#sns.kdeplot(df_ob26['Cls'].astype(float), alpha = 0.75, color = "red")
#sns.kdeplot(df_ob51['Cls'].astype(float), alpha = 0.5, color = "green")
sns.kdeplot(df_ob76['Cls'].astype(float), alpha = 0.75, color = "red")
